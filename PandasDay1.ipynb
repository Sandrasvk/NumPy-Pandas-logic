# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
labels = ['a', 'b', 'c']
my_list = [10, 20, 30]
arr = np.array([10, 20, 30])
d = { 'a' : 10, 'b': 20, 'c': 30}

# %%
pd.Series(data = my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data = my_list, index = labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_list, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int32

# %%
pd.Series(arr, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
series1 = pd.Series([1, 2, 3, 4], index = ['USA', 'GERMANY', 'USSR', 'JAPAN'])
series1
# Out:
# USA        1
# GERMANY    2
# USSR       3
# JAPAN      4
# dtype: int64

# %%
series2 = pd.Series([1, 2, 5, 4], index = ['USA', 'GERMANY', 'ITALY', 'JAPAN'])
series2
# Out:
# USA        1
# GERMANY    2
# ITALY      5
# JAPAN      4
# dtype: int64

# %%
series1 + series2
# Out:
# GERMANY    4.0
# ITALY      NaN
# JAPAN      8.0
# USA        2.0
# USSR       NaN
# dtype: float64

# %%
series1['USA']
# Out:
# 1

# %% [markdown]
#  Dataframes - Two dimensional hetrogeneous data more than one column, Series - One Dimensional homogenous

# %%
temp = np.random.randint(20, 100, 20)
name = np.random.choice(['Anu', 'Aravind', 'Ajay', 'Achu',], 20)
random = np.random.choice([10, 11, 12, 13, 14], 20)

# %%
a = list(zip(temp, name, random))

# %%
df = pd.DataFrame(data = a, columns = ['temp', 'name', 'random'])
df
# Out:
#     temp     name  random
# 0     47     Achu      14
# 1     25     Achu      11
# 2     59      Anu      11
# 3     74     Ajay      12
# 4     74  Aravind      14
# 5     62      Anu      10
# 6     24      Anu      10
# 7     33      Anu      10
# 8     74     Achu      11
# 9     90      Anu      14
# 10    83     Ajay      13
# 11    39     Ajay      13
# 12    98  Aravind      14
# 13    21  Aravind      11
# 14    61     Ajay      11
# 15    31  Aravind      10
# 16    63     Achu      11
# 17    71      Anu      13
# 18    59     Achu      12
# 19    99      Anu      11

# %%
np.random.seed(101)

# %%
temp = np.random.randint(20, 100, 20)
name = np.random.choice(['Anu', 'Aravind', 'Ajay', 'Achu',], 20)
random = np.random.choice([10, 11, 12, 13, 14], 20)
a = list(zip(temp, name, random))
df = pd.DataFrame(data = a, columns = ['temp', 'name', 'random'])
df
# Out:
#     temp     name  random
# 0     31      Anu      14
# 1     90      Anu      12
# 2     83  Aravind      14
# 3     95     Achu      10
# 4     29     Ajay      11
# 5     97     Ajay      14
# 6     60      Anu      12
# 7     24     Achu      14
# 8     83     Achu      10
# 9     60     Achu      14
# 10    80      Anu      12
# 11    84  Aravind      14
# 12    25     Achu      11
# 13    32  Aravind      10
# 14    60     Achu      13
# 15    69      Anu      13
# 16    28     Ajay      11
# 17    49      Anu      10
# 18    79     Achu      14
# 19    54     Achu      14

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(randn(5, 4), index ='A B C D E'.split(), columns = 'W X Y Z'.split())
df
# Out:
#           W         X         Y         Z
# A  1.029048 -0.272079  2.060797 -1.046867
# B -2.273739  1.218096 -0.662684  0.420491
# C -0.260526  0.389780  0.164244 -0.371581
# D -0.050739  2.434601  1.241440  0.190978
# E -1.245347  0.952183  1.301380 -0.167320

# %%
df['W']
# Out:
# A    1.029048
# B   -2.273739
# C   -0.260526
# D   -0.050739
# E   -1.245347
# Name: W, dtype: float64

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
df['W']
# Out:
# A    1.029048
# B   -2.273739
# C   -0.260526
# D   -0.050739
# E   -1.245347
# Name: W, dtype: float64

# %%
type(df[['W', 'Z']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['new'] = df['W'] + df['Y']
df
# Out:
#           W         X         Y         Z       new
# A  1.029048 -0.272079  2.060797 -1.046867  3.089845
# B -2.273739  1.218096 -0.662684  0.420491 -2.936423
# C -0.260526  0.389780  0.164244 -0.371581 -0.096282
# D -0.050739  2.434601  1.241440  0.190978  1.190701
# E -1.245347  0.952183  1.301380 -0.167320  0.056033

# %%
df.drop('new', axis = 1)
# Out:
#           W         X         Y         Z
# A  1.029048 -0.272079  2.060797 -1.046867
# B -2.273739  1.218096 -0.662684  0.420491
# C -0.260526  0.389780  0.164244 -0.371581
# D -0.050739  2.434601  1.241440  0.190978
# E -1.245347  0.952183  1.301380 -0.167320

# %%
df
# Out:
#           W         X         Y         Z       new
# A  1.029048 -0.272079  2.060797 -1.046867  3.089845
# B -2.273739  1.218096 -0.662684  0.420491 -2.936423
# C -0.260526  0.389780  0.164244 -0.371581 -0.096282
# D -0.050739  2.434601  1.241440  0.190978  1.190701
# E -1.245347  0.952183  1.301380 -0.167320  0.056033

# %%
df.drop('new', axis = 1, inplace = True)
df
# Out:
#           W         X         Y         Z
# A  1.029048 -0.272079  2.060797 -1.046867
# B -2.273739  1.218096 -0.662684  0.420491
# C -0.260526  0.389780  0.164244 -0.371581
# D -0.050739  2.434601  1.241440  0.190978
# E -1.245347  0.952183  1.301380 -0.167320

# %%
df.drop('A', axis = 0, inplace = True)
df
# Out:
#           W         X         Y         Z
# B -2.273739  1.218096 -0.662684  0.420491
# C -0.260526  0.389780  0.164244 -0.371581
# D -0.050739  2.434601  1.241440  0.190978
# E -1.245347  0.952183  1.301380 -0.167320

# %%
newdf = df.drop('E', axis = 0, inplace = True)
newdf

# %%
df
# Out:
#           W         X         Y         Z
# B -2.273739  1.218096 -0.662684  0.420491
# C -0.260526  0.389780  0.164244 -0.371581
# D -0.050739  2.434601  1.241440  0.190978

# %%
df.loc['B']
# Out:
# W   -2.273739
# X    1.218096
# Y   -0.662684
# Z    0.420491
# Name: B, dtype: float64

# %%
df.iloc[2]
# Out:
# W   -0.050739
# X    2.434601
# Y    1.241440
# Z    0.190978
# Name: D, dtype: float64

# %%
df.loc['B', 'Y']
# Out:
# -0.6626842470069781

# %%
df = pd.DataFrame(randn(5, 4), index ='A B C D E'.split(), columns = 'W X Y Z'.split())
df
# Out:
#           W         X         Y         Z
# A  0.050221  1.556790  1.345434  1.501737
# B -0.633348 -0.487281 -1.647469  0.543758
# C -1.210949 -0.365949  0.632181 -0.393214
# D -1.826066  1.257824  1.291497 -0.200139
# E  1.255905 -0.621076 -0.090848  0.439521

# %%
df.loc[['A', 'B'], ['W', 'Y']]
# Out:
#           W         Y
# A  0.050221  1.345434
# B -0.633348 -1.647469

# %%
df.set_index('Y', inplace = True)
df
# Out:
#                   W         X         Z
# Y
#  1.345434  0.050221  1.556790  1.501737
# -1.647469 -0.633348 -0.487281  0.543758
#  0.632181 -1.210949 -0.365949 -0.393214
#  1.291497 -1.826066  1.257824 -0.200139
# -0.090848  1.255905 -0.621076  0.439521

# %%
df.sort_index(axis = 0, ascending = True)
# Out:
#                   W         X         Z
# Y
# -1.647469 -0.633348 -0.487281  0.543758
# -0.090848  1.255905 -0.621076  0.439521
#  0.632181 -1.210949 -0.365949 -0.393214
#  1.291497 -1.826066  1.257824 -0.200139
#  1.345434  0.050221  1.556790  1.501737

# %%
df.sort_index(axis = 1, ascending = False)
# Out:
#                   Z         X         W
# Y
#  1.345434  1.501737  1.556790  0.050221
# -1.647469  0.543758 -0.487281 -0.633348
#  0.632181 -0.393214 -0.365949 -1.210949
#  1.291497 -0.200139  1.257824 -1.826066
# -0.090848  0.439521 -0.621076  1.255905

# %%
df.sort_values('X', ascending = False)
# Out:
#                   W         X         Z
# Y
#  1.345434  0.050221  1.556790  1.501737
#  1.291497 -1.826066  1.257824 -0.200139
#  0.632181 -1.210949 -0.365949 -0.393214
# -1.647469 -0.633348 -0.487281  0.543758
# -0.090848  1.255905 -0.621076  0.439521

# %%
df.reset_index(inplace = True)
df
# Out:
#           Y         W         X         Z
# 0  1.345434  0.050221  1.556790  1.501737
# 1 -1.647469 -0.633348 -0.487281  0.543758
# 2  0.632181 -1.210949 -0.365949 -0.393214
# 3  1.291497 -1.826066  1.257824 -0.200139
# 4 -0.090848  1.255905 -0.621076  0.439521

# %%
#conditional selection
df > 0
# Out:
#        Y      W      X      Z
# 0   True   True   True   True
# 1  False  False  False   True
# 2   True  False  False  False
# 3   True  False   True  False
# 4  False   True  False   True

# %%
df[df>0]
# Out:
#           Y         W         X         Z
# 0  1.345434  0.050221  1.556790  1.501737
# 1       NaN       NaN       NaN  0.543758
# 2  0.632181       NaN       NaN       NaN
# 3  1.291497       NaN  1.257824       NaN
# 4       NaN  1.255905       NaN  0.439521

# %%
df[df['W']>0]
# Out:
#           Y         W         X         Z
# 0  1.345434  0.050221  1.556790  1.501737
# 4 -0.090848  1.255905 -0.621076  0.439521

# %%
df[df['W']>0]['Y']
# Out:
# 0    1.345434
# 4   -0.090848
# Name: Y, dtype: float64

# %%
df[df['W']>0][['Y', 'X']]
# Out:
#           Y         X
# 0  1.345434  1.556790
# 4 -0.090848 -0.621076

# %%
df[(df['W']>0) & (df['Y']>1)]
# Out:
#           Y         W        X         Z
# 0  1.345434  0.050221  1.55679  1.501737

# %%
a = [1, 2, 3, 4, 5]
b = ['a' ,'b', 'c' ,'d' , 'e']
df = pd.DataFrame(a, b, columns = ['A'])
df
# Out:
#    A
# a  1
# b  2
# c  3
# d  4
# e  5

# %%
dmap = {1 : 'One', 2 : 'Two', 3 : 'Three', 4 : 'Four'}
df['A'].map(dmap)
# Out:
# a      One
# b      Two
# c    Three
# d     Four
# e      NaN
# Name: A, dtype: object
